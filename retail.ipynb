# %%
import pandas as pd

df = pd.read_csv("customer_shopping_data.csv")

df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
df.shape
# Out:
# (99457, 10)

# %%
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
df.isnull().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.countplot(x='category', data=df)
plt.xticks(rotation=45)
plt.title("Sales Count by Category")
plt.show()

# %%
df.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
df.nunique()
# Out:
# invoice_no        99457
# customer_id       99457
# gender                2
# age                  52
# category              8
# quantity              5
# price                40
# payment_method        3
# invoice_date        797
# shopping_mall        10
# dtype: int64

# %%
df['gender'].unique()
df['category'].unique()
df['payment_method'].unique()
# Out:
# array(['Credit Card', 'Debit Card', 'Cash'], dtype=object)

# %%
df.dtypes
# Out:
# invoice_no         object
# customer_id        object
# gender             object
# age                 int64
# category           object
# quantity            int64
# price             float64
# payment_method     object
# invoice_date       object
# shopping_mall      object
# dtype: object

# %%
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
df['invoice_date'] = pd.to_datetime(df['invoice_date'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    40029 non-null  datetime64[ns]
#  9   shopping_mall   99457 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(6)
# memory usage: 7.6+ MB

# %%
df['month'] = df['invoice_date'].dt.month
df['year'] = df['invoice_date'].dt.year
df['day'] = df['invoice_date'].dt.day

# %%
df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall  month    year   day
# 0    Credit Card   2022-05-08          Kanyon    5.0  2022.0   8.0
# 1     Debit Card   2021-12-12  Forum Istanbul   12.0  2021.0  12.0
# 2           Cash   2021-09-11       Metrocity    9.0  2021.0  11.0
# 3    Credit Card          NaT    Metropol AVM    NaN     NaN   NaN
# 4           Cash          NaT          Kanyon    NaN     NaN   NaN

# %%
df['month'] = df['invoice_date'].dt.month
df['year'] = df['invoice_date'].dt.year
df['day'] = df['invoice_date'].dt.day
df['day_name'] = df['invoice_date'].dt.day_name()

df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall  month    year   day  day_name
# 0    Credit Card   2022-05-08          Kanyon    5.0  2022.0   8.0    Sunday
# 1     Debit Card   2021-12-12  Forum Istanbul   12.0  2021.0  12.0    Sunday
# 2           Cash   2021-09-11       Metrocity    9.0  2021.0  11.0  Saturday
# 3    Credit Card          NaT    Metropol AVM    NaN     NaN   NaN       NaN
# 4           Cash          NaT          Kanyon    NaN     NaN   NaN       NaN

# %%
total_revenue = df['price'].sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 68551365.91

# %%
df.groupby('category')['price'].sum().sort_values(ascending=False)
# Out:
# category
# Clothing           31075684.64
# Shoes              18135336.89
# Technology         15772050.00
# Cosmetics           1848606.90
# Toys                1086704.64
# Food & Beverage      231568.71
# Books                226977.30
# Souvenir             174436.83
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
df.groupby('category')['price'].sum().sort_values().plot(kind='bar')
plt.title("Revenue by Category")
plt.xlabel("Category")
plt.ylabel("Revenue")
plt.show()

# %%
plt.figure(figsize=(8,5))
df.groupby('month')['price'].sum().plot(kind='line', marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %%
sns.countplot(x='gender', data=df)
plt.title("Customer Gender Distribution")
plt.show()

# %%
df.to_csv("cleaned_retail_data.csv", index=False)
